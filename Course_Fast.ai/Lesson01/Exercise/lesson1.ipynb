# %% [markdown]
# ## Is it a bird?

# %% [markdown]
# ## Prerequisites

# %%
#NB: Kaggle requires phone verification to use the internet or a GPU. If you haven't done that yet, the cell below will fail
#    This code is only here to check that your internet is enabled. It doesn't do anything else.
#    Here's a help thread on getting your phone number verified: https://www.kaggle.com/product-feedback/135367

import socket,warnings

try:
    socket.setdefaulttimeout(1)
    socket.socket(socket.AF_INET, socket.SOCK_STREAM).connect(('1.1.1.1', 53))
    print("Hi, JM!\nThis code is working...")
except socket.error as ex: raise Exception("STOP: No internet. Click '>|' in top right and set 'Internet' switch to on")
# Out:
# Hi, JM!
# This code is working...

# %%
# It's a good idea to ensure you're running the latest version of any libraries you need.
# `!pip install -Uqq <libraries>` upgrades to the latest version of <libraries>
# NB: You can safely ignore any warnings or errors pip spits out about running as root or incompatibilities

# NOTE: Ignore this file if you've already downloaded these two

# !pip install fastai "ddgs>=6.2"

print("Running")
# Out:
# Requirement already satisfied: fastai in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (2.8.7)
# Requirement already satisfied: ddgs>=6.2 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (9.14.4)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from fastai) (0.0.7)
# Requirement already satisfied: fastcore>=1.8.0 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from fastai) (1.13.2)
# Requirement already satisfied: fasttransform>=0.0.2 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from fastai) (0.0.2)
# Requirement already satisfied: torchvision>=0.11 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from fastai) (0.27.0)
# Requirement already satisfied: matplotlib in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from fastai) (3.10.9)
# Requirement already satisfied: pandas in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from fastai) (3.0.3)
# Requirement already satisfied: requests in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from fastai) (2.33.1)
# Requirement already satisfied: pyyaml in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from fastai) (6.0.3)
# Requirement already satisfied: fastprogress>=0.2.4 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from fastai) (1.1.6)
# Requirement already satisfied: pillow>=9.0.0 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from fastai) (12.2.0)
# Requirement already satisfied: scikit-learn in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from fastai) (1.8.0)
# Requirement already satisfied: scipy in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from fastai) (1.17.1)
# Requirement already satisfied: spacy<4 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from fastai) (3.8.13)
# Requirement already satisfied: packaging in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from fastai) (26.2)
# Requirement already satisfied: plum-dispatch in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from fastai) (2.9.0)
# Requirement already satisfied: cloudpickle in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from fastai) (3.1.2)
# Requirement already satisfied: torch<3,>=1.10 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from fastai) (2.12.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy<4->fastai) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy<4->fastai) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy<4->fastai) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy<4->fastai) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy<4->fastai) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy<4->fastai) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy<4->fastai) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy<4->fastai) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy<4->fastai) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy<4->fastai) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy<4->fastai) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy<4->fastai) (0.26.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy<4->fastai) (4.67.3)
# Requirement already satisfied: numpy>=1.19.0 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy<4->fastai) (2.4.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy<4->fastai) (2.12.5)
# Requirement already satisfied: jinja2 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy<4->fastai) (3.1.6)
# Requirement already satisfied: setuptools in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy<4->fastai) (81.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy<4->fastai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy<4->fastai) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy<4->fastai) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy<4->fastai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests->fastai) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests->fastai) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests->fastai) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests->fastai) (2026.2.25)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from thinc<8.4.0,>=8.3.12->spacy<4->fastai) (1.3.3)
# Requirement already satisfied: filelock in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from torch<3,>=1.10->fastai) (3.29.0)
# Requirement already satisfied: sympy>=1.13.3 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from torch<3,>=1.10->fastai) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from torch<3,>=1.10->fastai) (3.6.1)
# Requirement already satisfied: fsspec>=0.8.5 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from torch<3,>=1.10->fastai) (2026.4.0)
# Requirement already satisfied: colorama in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<4->fastai) (0.4.6)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<4->fastai) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<4->fastai) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<4->fastai) (0.0.4)
# Requirement already satisfied: cloudpathlib>=0.7.0 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy<4->fastai) (0.24.0)
# Requirement already satisfied: smart-open>=5.2.1 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy<4->fastai) (7.6.1)
# Requirement already satisfied: httpx>=0.24.0 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy<4->fastai) (0.28.1)
# Requirement already satisfied: click>=8.1.8 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ddgs>=6.2) (8.3.2)
# Requirement already satisfied: primp>=1.2.3 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ddgs>=6.2) (1.3.1)
# Requirement already satisfied: lxml>=4.9.4 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ddgs>=6.2) (6.1.1)
# Requirement already satisfied: fake-useragent>=2.2.0 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ddgs>=6.2) (2.2.0)
# Requirement already satisfied: python-fasthtml>=0.12.34 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from fastprogress>=0.2.4->fastai) (0.14.2)
# Requirement already satisfied: anyio in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy<4->fastai) (4.13.0)
# Requirement already satisfied: httpcore==1.* in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy<4->fastai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy<4->fastai) (0.16.0)
# Requirement already satisfied: brotli in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs>=6.2) (1.2.0)
# Requirement already satisfied: h2<5,>=3 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs>=6.2) (4.3.0)
# Requirement already satisfied: socksio==1.* in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs>=6.2) (1.0.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs>=6.2) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs>=6.2) (4.1.0)
# Requirement already satisfied: python-dateutil in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (2.9.0.post0)
# Requirement already satisfied: starlette>=1.0.1 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (1.2.1)
# Requirement already satisfied: oauthlib in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (3.3.1)
# Requirement already satisfied: itsdangerous in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (2.2.0)
# Requirement already satisfied: uvicorn>=0.30 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from uvicorn[standard]>=0.30->python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (0.44.0)
# Requirement already satisfied: fastlite>=0.1.1 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (0.2.4)
# Requirement already satisfied: python-multipart in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (0.0.29)
# Requirement already satisfied: beautifulsoup4 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (4.14.3)
# Requirement already satisfied: apswutils>=0.1.2 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from fastlite>=0.1.1->python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (0.1.2)
# Requirement already satisfied: apsw in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from apswutils>=0.1.2->fastlite>=0.1.1->python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (3.53.1.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy<4->fastai) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy<4->fastai) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy<4->fastai) (0.1.2)
# Requirement already satisfied: wrapt in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy<4->fastai) (2.2.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from sympy>=1.13.3->torch<3,>=1.10->fastai) (1.3.0)
# Requirement already satisfied: httptools>=0.6.3 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from uvicorn[standard]>=0.30->python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (0.8.0)
# Requirement already satisfied: python-dotenv>=0.13 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from uvicorn[standard]>=0.30->python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (1.2.2)
# Requirement already satisfied: watchfiles>=0.20 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from uvicorn[standard]>=0.30->python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (1.2.0)
# Requirement already satisfied: websockets>=10.4 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from uvicorn[standard]>=0.30->python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (16.0)
# Requirement already satisfied: soupsieve>=1.6.1 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from beautifulsoup4->python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (2.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jinja2->spacy<4->fastai) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib->fastai) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib->fastai) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib->fastai) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib->fastai) (1.5.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib->fastai) (3.3.2)
# Requirement already satisfied: six>=1.5 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from python-dateutil->python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (1.17.0)
# Requirement already satisfied: tzdata in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas->fastai) (2026.2)
# Requirement already satisfied: beartype>=0.22.2 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from plum-dispatch->fastai) (0.22.9)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-learn->fastai) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\JM\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-learn->fastai) (3.6.0)
# Running

# %% [markdown]
# In 2015 the idea of creating a computer system that could recognise birds was considered so outrageously challenging that it was the basis of [this XKCD joke](https://xkcd.com/1425/):

# %% [markdown]
# ![image.png](attachment:a0483178-c30e-4fdd-b2c2-349e130ab260.png)

# %% [markdown]
# But today, we can do exactly that, in just a few minutes, using entirely free resources!
#
# The basic steps we'll take are:
#
# 1. Use DuckDuckGo to search for images of "bird photos"
# 1. Use DuckDuckGo to search for images of "forest photos"
# 1. Fine-tune a pretrained neural network to recognise these two groups
# 1. Try running this model on a picture of a bird and see if it works.

# %% [markdown]
# ## Step 1: Download images of birds and non-birds

# %%
from ddgs import DDGS #DuckDuckGo has changed the api so we need to update 
from fastcore.all import *


def search_images(keywords, max_images=30): 
    print(f"Searching for {keywords}")
    return L(DDGS().images(keywords, max_results=max_images)).itemgot('image')
import time, json

# %% [markdown]
# Let's start by searching for a bird photo and seeing what kind of result we get. We'll start by getting URLs from a search:

# %%
#NB: `search_images` depends on duckduckgo.com, which doesn't always return correct responses.
#    If you get a JSON error, just try running it again (it may take a couple of tries).
urls = search_images('bird photos', max_images=1) # Query images: "bird photos" and get 1
urls[0]
# Out:
# Searching for bird photos
# 'https://images.pexels.com/photos/326900/pexels-photo-326900.jpeg?cs=srgb&dl=wood-flight-bird-326900.jpg&fm=jpg'

# %% [markdown]
# ...and then download a URL and take a look at it:

# %%
# Import fast downloader library
from fastdownload import download_url
dest = 'bird.jpg'
download_url(urls[0], dest, show_progress=False)

from fastai.vision.all import *
im = Image.open(dest)
im.to_thumb(256,256)
# Out:
# <PIL.Image.Image image mode=RGB size=256x171>

# %% [markdown]
# Now let's do the same with "forest photos":

# %%
download_url(search_images('forest photos', max_images=1)[0], 'forest.jpg', show_progress=False)
Image.open('forest.jpg').to_thumb(256,256)
# Out:
# Searching for forest photos
# <PIL.Image.Image image mode=RGB size=256x144>

# %% [markdown]
# Our searches seem to be giving reasonable results, so let's grab a few examples of each of "bird" and "forest" photos, and save each group of photos to a different folder:

# %%
searches = 'forest','bird'
path = Path('bird_or_not')

for o in searches:
    dest = (path/o)
    dest.mkdir(exist_ok=True, parents=True)
    download_images(dest, urls=search_images(f'{o} photo'))
    time.sleep(5)
    resize_images(path/o, max_size=400, dest=path/o)
# Out:
# Searching for forest photo
# Searching for bird photo

# %% [markdown]
# ## Step 2: Train our model

# %% [markdown]
# Some photos might not download correctly which could cause our model training to fail, so we'll remove them:

# %%
failed = verify_images(get_image_files(path))
failed.map(Path.unlink)
len(failed)
# Out:
# 0

# %% [markdown]
# To train a model, we'll need `DataLoaders`, which is an object that contains a *training set* (the images used to create a model) and a *validation set* (the images used to check the accuracy of a model -- not used during training). In `fastai` we can create that easily using a `DataBlock`, and view sample images from it:

# %%
dls = DataBlock(
    # What kind of input do we have?
    blocks=(ImageBlock, CategoryBlock), 
    
    # What are the items in this model?
    get_items=get_image_files, 

    # CRITICAL: Randomly set aside 20% of the data
    # Called a VALIDATION SET
    splitter=RandomSplitter(valid_pct=0.2, seed=42), 

    # How do we know if image is bird or forest photo?
    get_y=parent_label,

    # All of the bits of code that will run in every item
    # Resize everything to size "192" bu "squish"ing it
    item_tfms=[Resize(192, method='squish')]
).dataloaders(path, bs=32)

# Show image batch (label and image)
dls.show_batch(max_n=6)

# %% [markdown]
# Here what each of the `DataBlock` parameters means:
#
#     blocks=(ImageBlock, CategoryBlock),
#
# The inputs to our model are images, and the outputs are categories (in this case, "bird" or "forest").
#
#     get_items=get_image_files,
#
# To find all the inputs to our model, run the `get_image_files` function (which returns a list of all image files in a path).
#
#     splitter=RandomSplitter(valid_pct=0.2, seed=42),
#
# Split the data into training and validation sets randomly, using 20% of the data for the validation set.
#
#     get_y=parent_label,
#
# The labels (`y` values) is the name of the `parent` of each file (i.e. the name of the folder they're in, which will be *bird* or *forest*).
#
#     item_tfms=[Resize(192, method='squish')]
#
# Before training, resize each image to 192x192 pixels by "squishing" it (as opposed to cropping it).

# %% [markdown]
# Now we're ready to train our model. The fastest widely used computer vision model is `resnet18`. You can train this in a few minutes, even on a CPU! (On a GPU, it generally takes under 10 seconds...)
#
# `fastai` comes with a helpful `fine_tune()` method which automatically uses best practices for fine tuning a pre-trained model, so we'll use that.

# %%
# Combines a model (neural network we're training) and data we train it with
# Gets the data (data loaders) and the model (neural network function)

# dls: dataloader
# resnet18: neural network model (fast.ai built-in)
learn = vision_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(3)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 136MB/s]
# <style>
#     progress { appearance: none; border: none; border-radius: 4px; width: 300px;
#         height: 20px; vertical-align: middle; background: #e0e0e0; }
#
#     progress::-webkit-progress-bar { background: #e0e0e0; border-radius: 4px; }
#     progress::-webkit-progress-value { background: #2196F3; border-radius: 4px; }
#     progress::-moz-progress-bar { background: #2196F3; border-radius: 4px; }
#
#     progress:not([value]) {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px); }
#
#     progress.progress-bar-interrupted::-webkit-progress-value { background: #F44336; }
#     progress.progress-bar-interrupted::-moz-progress-value { background: #F44336; }
#     progress.progress-bar-interrupted::-webkit-progress-bar { background: #F44336; }
#     progress.progress-bar-interrupted::-moz-progress-bar { background: #F44336; }
#     progress.progress-bar-interrupted { background: #F44336; }
#
#     table.fastprogress { border-collapse: collapse; margin: 1em 0; font-size: 0.9em; }
#     table.fastprogress th, table.fastprogress td { padding: 8px 12px; border: 1px solid #ddd; text-align: left; }
#     table.fastprogress thead tr { background: #f8f9fa; font-weight: bold; }
#     table.fastprogress tbody tr:nth-of-type(even) { background: #f8f9fa; }
# </style>
# <div><table class="fastprogress"><thead><tr><th>epoch</th><th>train_loss</th><th>valid_loss</th><th>error_rate</th><th>time</th></tr></thead><tbody><tr><td>0</td><td>1.200706</td><td>2.015864</td><td>0.333333</td><td>00:02</td></tr></tbody></table></div>
# <div><table class="fastprogress"><thead><tr><th>epoch</th><th>train_loss</th><th>valid_loss</th><th>error_rate</th><th>time</th></tr></thead><tbody><tr><td>0</td><td>1.170596</td><td>1.517771</td><td>0.333333</td><td>00:00</td></tr><tr><td>1</td><td>0.926056</td><td>0.992950</td><td>0.333333</td><td>00:00</td></tr><tr><td>2</td><td>0.652621</td><td>0.482965</td><td>0.333333</td><td>00:00</td></tr></tbody></table></div>

# %% [markdown]
# Generally when I run this I see 100% accuracy on the validation set (although it might vary a bit from run to run).
#
# "Fine-tuning" a model means that we're starting with a model someone else has trained using some other dataset (called the *pretrained model*), and adjusting the weights a little bit so that the model learns to recognise your particular dataset. In this case, the pretrained model was trained to recognise photos in *imagenet*, and widely-used computer vision dataset with images covering 1000 categories) For details on fine-tuning and why it's important, check out the [free fast.ai course](https://course.fast.ai/).

# %% [markdown]
# ## Step 3: Use our model (and build your own!)

# %% [markdown]
# Let's see what our model thinks about that bird we downloaded at the start:

# %%
is_bird,_,probs = learn.predict(PILImage.create('bird.jpg'))
print(f"This is a: {is_bird}.")
print(f"Probability it's a bird: {probs[0]:.4f}")
# Out:
# This is a: bird.
# Probability it's a bird: 1.0000

# %% [markdown]
# Good job, resnet18. :)
#
# So, as you see, in the space of a few years, creating computer vision classification models has gone from "so hard it's a joke" to "trivially easy and free"!
#
# It's not just in computer vision. Thanks to deep learning, computers can now do many things which seemed impossible just a few years ago, including [creating amazing artworks](https://openai.com/dall-e-2/), and [explaining jokes](https://www.datanami.com/2022/04/22/googles-massive-new-language-model-can-explain-jokes/). It's moving so fast that even experts in the field have trouble predicting how it's going to impact society in the coming years.
#
# One thing is clear -- it's important that we all do our best to understand this technology, because otherwise we'll get left behind!

# %% [markdown]
# Now it's your turn. Click "Copy & Edit" and try creating your own image classifier using your own image searches!
#
# If you enjoyed this, please consider clicking the "upvote" button in the top-right -- it's very encouraging to us notebook authors to know when people appreciate our work.
